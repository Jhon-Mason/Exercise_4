# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

card_deck = [
    {"Name": "Diablo", "Health": 100, "Attack": 90, "Defense": 60},
    {"Name": "Medusa", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Jester", "Health": 120, "Attack": 60, "Defense": 90},
    {"Name": "Troll", "Health": 150, "Attack": 40, "Defense": 94},
    {"Name": "Specter", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Mist", "Health": 100, "Attack": 75, "Defense": 65},
    {"Name": "Savage", "Health": 100, "Attack": 90, "Defense": 50},
    {"Name": "Marauder", "Health": 100, "Attack": 85, "Defense": 50},
    {"Name": "Wimp", "Health": 110, "Attack": 40, "Defense": 85},
    {"Name": "Sorcerer", "Health": 100, "Attack": 70, "Defense": 55}
]

def display_card(card):
    print(f"Name: {card['Name']}, Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']}")

def battle(player_card, opponent_card):
    print(f"\nBattle begins between {player_card['Name']} and {opponent_card['Name']}!")
    
    if player_card['Attack'] >= opponent_card['Health']:
        print(f"{player_card['Name']} defeats {opponent_card['Name']} with a direct attack!")
        return True
    else:
        attack_after_defense = max(player_card['Attack'] - opponent_card['Defense'], 0)
        if attack_after_defense > 0:
            opponent_card['Defense'] = max(opponent_card['Defense'] - player_card['Attack'], 0)
            if opponent_card['Defense'] == 0:
                opponent_card['Health'] -= attack_after_defense
        
        print(f"After the attack, {opponent_card['Name']}'s Defense is now {opponent_card['Defense']} and Health is {opponent_card['Health']}")
        
        if opponent_card['Health'] <= 0:
            print(f"{opponent_card['Name']} has been defeated!")
            return True
        return False

def opponent_battle(opponent_card, player_card):
    print(f"\nOpponent's turn! {opponent_card['Name']} attacks {player_card['Name']}!")
    
    if opponent_card['Attack'] >= player_card['Health']:
        print(f"{opponent_card['Name']} defeats {player_card['Name']} with a direct attack!")
        return True
    else:
        attack_after_defense = max(opponent_card['Attack'] - player_card['Defense'], 0)
        if attack_after_defense > 0:
            player_card['Defense'] = max(player_card['Defense'] - opponent_card['Attack'], 0)
            if player_card['Defense'] == 0:
                player_card['Health'] -= attack_after_defense
        
        print(f"After the attack, {player_card['Name']}'s Defense is now {player_card['Defense']} and Health is {player_card['Health']}")
        
        if player_card['Health'] <= 0:
            print(f"{player_card['Name']} has been defeated!")
            return True
        return False

def game_loop():
    deck_size = 5
    player_deck = random.sample(card_deck, deck_size)
    opponent_deck = random.sample(card_deck, deck_size)

    print("\nGame Start! Each player gets 5 random cards.\n")

    while player_deck and opponent_deck:
        print("\nYour Deck:")
        for idx, card in enumerate(player_deck):
            print(f"{idx + 1}. {card['Name']} (Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']})")

        opponent_card = random.choice(opponent_deck)
        print("\nOpponent has drawn the following card:")
        display_card(opponent_card)

        choice = int(input("\nChoose a card to battle (1-5): ")) - 1
        player_card = player_deck[choice]

        if battle(player_card, opponent_card):
            opponent_deck.remove(opponent_card)
        else:
            time.sleep(3)
            if opponent_battle(opponent_card, player_card):
                player_deck.remove(player_card)

        print("\nNext round will start in 3 seconds...")
        time.sleep(3)

    if not opponent_deck:
        print("\nCongratulations! You have defeated all the opponent's cards!")
    elif not player_deck:
        print("\nYou lost! The opponent defeated all your cards.")

game_loop()
# Out:
# Game Start! Each player gets 5 random cards.
#
#
# Your Deck:
# 1. Specter (Health: 100, Attack: 70, Defense: 70)
# 2. Wimp (Health: 110, Attack: 40, Defense: 85)
# 3. Marauder (Health: 100, Attack: 85, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 94)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Savage, Health: 100, Attack: 90, Defense: 50
#
# Battle begins between Specter and Savage!
# After the attack, Savage's Defense is now 0 and Health is 80
#
# Opponent's turn! Savage attacks Specter!
# After the attack, Specter's Defense is now 0 and Health is 80
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Specter (Health: 80, Attack: 70, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 85)
# 3. Marauder (Health: 100, Attack: 85, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 94)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Troll, Health: 150, Attack: 40, Defense: 94
#
# Battle begins between Specter and Troll!
# After the attack, Troll's Defense is now 94 and Health is 150
#
# Opponent's turn! Troll attacks Specter!
# After the attack, Specter's Defense is now 0 and Health is 40
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Specter (Health: 40, Attack: 70, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 85)
# 3. Marauder (Health: 100, Attack: 85, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 94)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Specter, Health: 40, Attack: 70, Defense: 0
#
# Battle begins between Specter and Specter!
# Specter defeats Specter with a direct attack!
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Specter (Health: 40, Attack: 70, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 85)
# 3. Marauder (Health: 100, Attack: 85, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 94)
# 5. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
#
# Battle begins between Specter and Medusa!
# After the attack, Medusa's Defense is now 70 and Health is 100
#
# Opponent's turn! Medusa attacks Specter!
# Medusa defeats Specter with a direct attack!
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Mist, Health: 100, Attack: 75, Defense: 65
#
# Battle begins between Wimp and Mist!
# After the attack, Mist's Defense is now 65 and Health is 100
#
# Opponent's turn! Mist attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Troll, Health: 150, Attack: 40, Defense: 94
#
# Battle begins between Wimp and Troll!
# After the attack, Troll's Defense is now 94 and Health is 150
#
# Opponent's turn! Troll attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Mist, Health: 100, Attack: 75, Defense: 65
#
# Battle begins between Wimp and Mist!
# After the attack, Mist's Defense is now 65 and Health is 100
#
# Opponent's turn! Mist attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
#
# Battle begins between Wimp and Medusa!
# After the attack, Medusa's Defense is now 70 and Health is 100
#
# Opponent's turn! Medusa attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Mist, Health: 100, Attack: 75, Defense: 65
#
# Battle begins between Wimp and Mist!
# After the attack, Mist's Defense is now 65 and Health is 100
#
# Opponent's turn! Mist attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Troll, Health: 150, Attack: 40, Defense: 94
#
# Battle begins between Wimp and Troll!
# After the attack, Troll's Defense is now 94 and Health is 150
#
# Opponent's turn! Troll attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Troll, Health: 150, Attack: 40, Defense: 94
#
# Battle begins between Wimp and Troll!
# After the attack, Troll's Defense is now 94 and Health is 150
#
# Opponent's turn! Troll attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Troll, Health: 150, Attack: 40, Defense: 94
#
# Battle begins between Wimp and Troll!
# After the attack, Troll's Defense is now 94 and Health is 150
#
# Opponent's turn! Troll attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Mist, Health: 100, Attack: 75, Defense: 65
#
# Battle begins between Wimp and Mist!
# After the attack, Mist's Defense is now 65 and Health is 100
#
# Opponent's turn! Mist attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
#
# Battle begins between Wimp and Medusa!
# After the attack, Medusa's Defense is now 70 and Health is 100
#
# Opponent's turn! Medusa attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Mist, Health: 100, Attack: 75, Defense: 65
#
# Battle begins between Wimp and Mist!
# After the attack, Mist's Defense is now 65 and Health is 100
#
# Opponent's turn! Mist attacks Wimp!
# After the attack, Wimp's Defense is now 85 and Health is 110
#
# Next round will start in 3 seconds...
#
# Your Deck:
# 1. Wimp (Health: 110, Attack: 40, Defense: 85)
# 2. Marauder (Health: 100, Attack: 85, Defense: 50)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Jester (Health: 120, Attack: 60, Defense: 90)
#
# Opponent has drawn the following card:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Desktop\code\Non-graded-exercise-4\non_graded_ex_4.ipynb 单元格 2 line 9
#      <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=90'>91</a>     elif not player_deck:
#      <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=91'>92</a>         print("\nYou lost! The opponent defeated all your cards.")
# ---> <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=93'>94</a> game_loop()
#
# d:\Desktop\code\Non-graded-exercise-4\non_graded_ex_4.ipynb 单元格 2 line 7
#      <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=72'>73</a> print("\nOpponent has drawn the following card:")
#      <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=73'>74</a> display_card(opponent_card)
# ---> <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=75'>76</a> choice = int(input("\nChoose a card to battle (1-5): ")) - 1
#      <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=76'>77</a> player_card = player_deck[choice]
#      <a href='vscode-notebook-cell:/d%3A/Desktop/code/Non-graded-exercise-4/non_graded_ex_4.ipynb#W2sZmlsZQ%3D%3D?line=78'>79</a> if battle(player_card, opponent_card):
#
# ValueError: invalid literal for int() with base 10: ''
